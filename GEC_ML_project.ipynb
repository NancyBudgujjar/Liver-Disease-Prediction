# %% [markdown]
# <a href="https://colab.research.google.com/github/NancyBudgujjar/Liver-Disease-Prediction/blob/main/GEC_ML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/uciml/indian-liver-patient-records
#
# Prediction of Liver Disease using Random Forest classifierand balancing imbalanced data.
# This data set contains 416 liver patient records and 167 non liver patient records collected from North East of Andhra Pradesh, India.
# The "Dataset" column is a class label used to divide groups into liver patient (liver disease) or not (no disease).
# This data set contains 441 male patient records and 142 female patient records.Any patient whose age exceeded 89 is listed as being of age "90".

# %%
import numpy as np
import cv2
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/project/indian_liver_patient.csv')
df.shape
# Out:
# (583, 11)

# %%
df['Dataset'].value_counts()  # 1 = Liver disease and 2 is no disease
# Out:
# 1    416
# 2    167
# Name: Dataset, dtype: int64

# %%
categories = {1: 1, 2: 0}   #Now we map 1 = 1(Liver disease), 2 = 0(no disease)
df['Dataset'] = df['Dataset'].replace(categories)

#Define the dependent variable that needs to be predicted (labels)
#Y = df["Label"].values

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
df.describe().T  #Values need to be normalized before fitting.
# Out:
#                             count        mean         std   min    25%  \
# Age                         583.0   44.746141   16.189833   4.0   33.0
# Total_Bilirubin             583.0    3.298799    6.209522   0.4    0.8
# Direct_Bilirubin            583.0    1.486106    2.808498   0.1    0.2
# Alkaline_Phosphotase        583.0  290.576329  242.937989  63.0  175.5
# Alamine_Aminotransferase    583.0   80.713551  182.620356  10.0   23.0
# Aspartate_Aminotransferase  583.0  109.910806  288.918529  10.0   25.0
# Total_Protiens              583.0    6.483190    1.085451   2.7    5.8
# Albumin                     583.0    3.141852    0.795519   0.9    2.6
# Albumin_and_Globulin_Ratio  579.0    0.947064    0.319592   0.3    0.7
# Dataset                     583.0    0.713551    0.452490   0.0    0.0
#
#                                50%    75%     max
# Age                          45.00   58.0    90.0
# Total_Bilirubin               1.00    2.6    75.0
# Direct_Bilirubin              0.30    1.3    19.7
# Alkaline_Phosphotase        208.00  298.0  2110.0
# Alamine_Aminotransferase     35.00   60.5  2000.0
# Aspartate_Aminotransferase   42.00   87.0  4929.0
# Total_Protiens                6.60    7.2     9.6
# Albumin                       3.10    3.8     5.5
# Albumin_and_Globulin_Ratio    0.93    1.1     2.8
# Dataset                       1.00    1.0     1.0

# %%
print(df.isnull().sum())
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
print(df['Albumin_and_Globulin_Ratio'].mean())
# Out:
# 0.9470639032815197

# %%
df['Albumin_and_Globulin_Ratio'] = df['Albumin_and_Globulin_Ratio'].fillna(0.947)
print(df.isnull().sum())
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 13

# %%
#Rename Dataset to Label to make it easy to understand
df = df.rename(columns={'Dataset':'Label'})
print(df.dtypes)
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Label                           int64
# dtype: object

# %%
sns.countplot(x="Label", data=df)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
sns.countplot(x="Label", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
sns.displot(df['Age'], kde=False)

# %%
plt.figure(figsize=(20,10))
sns.countplot(x = 'Age', data = df, order = df['Age'].value_counts().index)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.scatterplot(x="Label", y="Albumin", data=df)  #Seems no trend between labels 1 and 2
# Out:
# <Axes: xlabel='Label', ylabel='Albumin'>

# %%
sns.scatterplot(x="Label", y="Albumin_and_Globulin_Ratio", data=df)  #Seems no trend between labels 1 and 2
# Out:
# <Axes: xlabel='Label', ylabel='Albumin_and_Globulin_Ratio'>

# %%
sns.scatterplot(x="Albumin", y="Albumin_and_Globulin_Ratio", data=df)  #Seems no trend between labels 1 and 2
# Out:
# <Axes: xlabel='Albumin', ylabel='Albumin_and_Globulin_Ratio'>

# %%
#sns.pairplot(df, hue='Gender')

# %%
corr=df.corr()
plt.figure(figsize=(20,12))
sns.heatmap(corr,cmap="Blues",linewidths=.5, annot=True)
#May be Gender and total protien not big factors influencing the label
# Out:
# <ipython-input-21-9569b0fec464>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %%
df['Gender'].value_counts()
# Out:
# Male      441
# Female    142
# Name: Gender, dtype: int64

# %%
categories = {"Male":1, "Female":0} #Replace categorical values with numbers
df['Gender'] = df['Gender'].replace(categories)

Y = df["Label"].values
#X = df.drop(labels = ["Label", "Gender"], axis=1)
X = df.drop(labels = ["Label"], axis=1)

# %%
#Split data into train and test to verify accuracy after fitting the model.
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets into 80,20 %
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape)
print(y_train.shape)
# Out:
# (466, 10)
# (466,)

# %%
from keras.utils import normalize
X = normalize(X, axis=1)

# %% [markdown]
# # Technique 1: Appropriate Model Selection
# Logistic regression :- Can be very slow.
#
# SVM :- can also be extremely slow.
#
# Random Forest :- ideal for imbalanced datasets.

# %% [markdown]
# #Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression(max_iter=900)

logreg.fit(X_train, y_train) # fit the model on the training data

y_pred = logreg.predict(X_test) # make predictions on the testing data

accuracy = metrics.accuracy_score(y_test, y_pred) # calculate accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7521367521367521

# %% [markdown]
# #Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
svm_model = SVC(kernel='linear')

svm_model.fit(X_train, y_train) # Train the SVM model on the training data
y_pred = svm_model.predict(X_test) # Make predictions on the test data

accuracy = metrics.accuracy_score(y_test, y_pred) # Calculate the accuracy of the SVM model
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7435897435897436

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier, VotingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

models= [
         ('Decision Tree', DecisionTreeClassifier()),
         ('RandomForestClassifier',RandomForestClassifier()),
         ('AdaBoostClassifier',AdaBoostClassifier()),
         ('XGBClassifier',XGBClassifier()),
         ('KNeighborsClassifier',KNeighborsClassifier()),
         ('GaussianNB',GaussianNB ())]

ModelName = []
Train_Acc = []
Test_Acc = []

for name, model in models:
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred  = model.predict(X_test)

    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)

    ModelName.extend([name])
    Train_Acc.extend([train_acc])
    Test_Acc.extend([test_acc])

print(pd.DataFrame({'ModelName': ModelName,
                    'Train_Acc': Train_Acc,
                    'Test_Acc': Test_Acc  }))
# Out:
#                 ModelName  Train_Acc  Test_Acc
# 0           Decision Tree   1.000000  0.700855
# 1  RandomForestClassifier   1.000000  0.777778
# 2      AdaBoostClassifier   0.806867  0.700855
# 3           XGBClassifier   1.000000  0.717949
# 4    KNeighborsClassifier   0.778970  0.683761
# 5              GaussianNB   0.551502  0.512821

# %% [markdown]
# #Random Forest

# %%
model_RF = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_RF.fit(X_train, y_train) # Train the model on training data

#importances = list(model_RF.feature_importances_)
features_list = list(X.columns)
feature_imp = pd.Series(model_RF.feature_importances_, index=features_list).sort_values(ascending=False)
print(feature_imp)
# Out:
# Alkaline_Phosphotase          0.159246
# Aspartate_Aminotransferase    0.130313
# Age                           0.127091
# Alamine_Aminotransferase      0.116930
# Total_Protiens                0.100839
# Total_Bilirubin               0.096881
# Albumin                       0.093977
# Direct_Bilirubin              0.077196
# Albumin_and_Globulin_Ratio    0.076954
# Gender                        0.020573
# dtype: float64

# %%
prediction_test_RF = model_RF.predict(X_test) #Test prediction on testing data.

print("METRICS FOR IMBALANCED DATA: ") #ACCURACY METRICS
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_test_RF))
# Out:
# METRICS FOR IMBALANCED DATA:
# Accuracy =  0.7350427350427351

# %%
(unique, counts) = np.unique(prediction_test_RF, return_counts=True)
print(unique, counts)
# Out:
# [0 1] [25 92]

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction_test_RF)
print("Confusion Metrics: \n", cm)
# Out:
# Confusion Metrics:
#  [[12 18]
#  [13 74]]

# %% [markdown]
# means 12 out of 25 labled are correctly as 0(healthy patient) and 13/22 are mislablled as 1, i.e., 13 are healthy patients but still labelled as 1.
#
# 74 our of 92 are correctly labled and 18 are mislablled.

# %%
#Print individual precision values for each class, based on the confusion matrix
print("Precision Values for: ")
P0 = cm[0,0] / (cm[0,0]+cm[1,0])
P1 = cm[1,1] / (cm[0,1]+cm[1,1])

print("  With NO Lung disease =", P0)
print("  With Lung disease =",   P1)
# Out:
# Precision Values for:
#   With NO Lung disease = 0.48
#   With Lung disease = 0.8043478260869565

# %%
#Print individual recall values for each class, based on the confusion matrix
print("Recall Values for: ")
R0 = cm[0,0] / (cm[0,0]+cm[0,1])
R1 = cm[1,1] / (cm[1,1]+cm[1,0])

print("  With NO Lung disease = ", R0 )
print("  With Lung disease = ", R1 )
# Out:
# Recall Values for:
#   With NO Lung disease =  0.4
#   With Lung disease =  0.8505747126436781

# %%
print("F-Measure Values for: ")
print("  With NO Lung disease = ", (2 * P0 * R0)/ (P0 + R0))
print("  With Lung disease = ", (2 * P1 * R1)/ (P1 + R1))
# Out:
# F-Measure Values for:
#   With NO Lung disease =  0.4363636363636364
#   With Lung disease =  0.8268156424581005

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html

# %%
from sklearn.metrics import roc_auc_score  #Version 0.23.1 of sklearn

print("ROC_AUC score for imbalanced data is: ", roc_auc_score(y_test, prediction_test_RF))
# Out:
# ROC_AUC score for imbalanced data is:  0.6252873563218391

# %%
from yellowbrick.classifier import ROCAUC

roc_auc=ROCAUC(model_RF)  #Create object
roc_auc.fit(X_train, y_train)
roc_auc.score(X_test, y_test)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# # Handling Imbalanced data

# %% [markdown]
# Technique 1: Generate synthetic data (SMOTE and ADASYN)
# SMOTE: Synthetic Minority Oversampling Technique
#
# ADASYN: Adaptive Synthetic
#
# https://imbalanced-learn.org/stable/over_sampling.html?highlight=smote
#
# pip install imblearn
#
# SMOTE may not be the best choice all the time. It is one of many things
# that you need to explore.

# %%
from imblearn.over_sampling import SMOTE
X_smote, Y_smote = SMOTE().fit_resample(X, Y)
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, Y_smote, test_size=0.2, random_state=42)

(unique, counts) = np.unique(Y, return_counts=True)
print("Original data: ", unique, counts)

(unique2, counts2) = np.unique(Y_smote, return_counts=True)
print("After SMOTE: ", unique2, counts2)
# Out:
# Original data:  [0 1] [167 416]
# After SMOTE:  [0 1] [416 416]

# %% [markdown]
# #Logestic Regression

# %%
model_LR = LogisticRegression(max_iter=900)
model_LR.fit(X_train_smote, y_train_smote)
LR_prediction_smote = model_LR.predict(X_test_smote)

accuracy = metrics.accuracy_score(y_test_smote, LR_prediction_smote)
print("Accuracy:", accuracy)
print("ROC AUC score for Logestic Regression model after SMOTE: ",roc_auc_score(y_test_smote, LR_prediction_smote))
# Out:
# Accuracy: 0.6347305389221557
# ROC AUC score for Logestic Regression model after SMOTE:  0.6302898550724638

# %%
roc_auc=ROCAUC(model_LR)
roc_auc.fit(X_train_smote, y_train_smote)
roc_auc.score(X_test_smote, y_test_smote)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for LogisticRegression'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #SVM

# %%
model_SVM = SVC(kernel='linear')
model_SVM.fit(X_train_smote, y_train_smote)
SVM_prediction_smote = model_SVM.predict(X_test_smote)

accuracy = metrics.accuracy_score(y_test_smote, SVM_prediction_smote)
print("Accuracy:", accuracy)
print("ROC AUC score for SVM model after SMOTE: ", roc_auc_score(y_test_smote, SVM_prediction_smote))
# Out:
# Accuracy: 0.6407185628742516
# ROC AUC score for SVM model after SMOTE:  0.6135507246376811

# %% [markdown]
# #Random Forest

# %%
model_SMOTE = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_SMOTE.fit(X_train_smote, y_train_smote)

prediction_test_smote = model_SMOTE.predict(X_test_smote)
print ("Accuracy = ", metrics.accuracy_score(y_test_smote, prediction_test_smote))
# Out:
# Accuracy =  0.7964071856287425

# %%
#Confusion Matrix
(unique, counts) = np.unique(prediction_test_smote, return_counts=True)
print(unique, counts)

cm = confusion_matrix(y_test_smote, prediction_test_smote)
print("Confusion Metrics after SMOTE: \n",cm)
# Out:
# [0 1] [98 69]
# Confusion Metrics after SMOTE:
#  [[78 14]
#  [20 55]]

# %%
print("Precision Values for: ")
P0 = cm[0,0] / (cm[0,0]+cm[1,0])
P1 = cm[1,1] / (cm[0,1]+cm[1,1])

print("  With NO Lung disease = ", P0)
print("  With Lung disease = ",   P1)
# Out:
# Precision Values for:
#   With NO Lung disease =  0.7959183673469388
#   With Lung disease =  0.7971014492753623

# %%
#Print individual recall values for each class, based on the confusion matrix
print("Recall Values for: ")
R0 = cm[0,0] / (cm[0,0]+cm[0,1])
R1 = cm[1,1] / (cm[1,1]+cm[1,0])
print("  With NO Lung disease = ", R0)
print("  With Lung disease = ", R1)
# Out:
# Recall Values for:
#   With NO Lung disease =  0.8478260869565217
#   With Lung disease =  0.7333333333333333

# %%
print("F-Measure Values for: ")
print("  With NO Lung disease = ", (2 * P0 * R0)/ (P0 + R0))
print("  With Lung disease = ", (2 * P1 * R1)/ (P1 + R1))
# Out:
# F-Measure Values for:
#   With NO Lung disease =  0.8210526315789473
#   With Lung disease =  0.7638888888888887

# %%
print("ROC AUC score for Random Forest model after SMOTE: ", roc_auc_score(y_test_smote, prediction_test_smote))
# Out:
# ROC AUC score for Random Forest model after SMOTE:  0.7905797101449276

# %%
from yellowbrick.classifier import ROCAUC
roc_auc=ROCAUC(model_SMOTE)
roc_auc.fit(X_train_smote, y_train_smote)
roc_auc.score(X_test_smote, y_test_smote)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #Handling Imbalanced Data using SMOTEENN
# It combines SMOTE and Edited Nearest Neighbours(ENN)

# %%
from imblearn.combine import SMOTEENN
smote_enn = SMOTEENN(random_state=0)
X_resampled, y_resampled = smote_enn.fit_resample(X, Y)
'''
from imblearn.combine import SMOTETomek
smote_tomek = SMOTETomek(random_state=0)
X_resampled, y_resampled = smote_tomek.fit_resample(X, Y)
'''
X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %%
model_LR = LogisticRegression(max_iter=900)
model_LR.fit(X_train_smote, y_train_smote)
LR_prediction_smote = model_LR.predict(X_test_smote)

accuracy = metrics.accuracy_score(y_test_smote, LR_prediction_smote)
print("Accuracy of Logistic Regression after SMOTEENN:", accuracy)
print("ROC AUC score for Logistic Regression model after SMOTEENN: ", roc_auc_score(y_test_smote, LR_prediction_smote))
# Out:
# Accuracy of Logistic Regression after SMOTEENN: 0.775
# ROC AUC score for Logistic Regression model after SMOTEENN:  0.7045300878972279

# %%
model_SVM = SVC(kernel='linear')
model_SVM.fit(X_train_smote, y_train_smote)
SVM_prediction_smote = model_SVM.predict(X_test_smote)

accuracy = metrics.accuracy_score(y_test_smote, SVM_prediction_smote)
print("Accuracy of SVM after SMOTEENN:", accuracy)
print("ROC AUC score for SVM model after SMOTEENN: ", roc_auc_score(y_test_smote, SVM_prediction_smote))
# Out:
# Accuracy of SVM after SMOTEENN: 0.775
# ROC AUC score for SVM model after SMOTEENN:  0.6970926301555105

# %%
model_SMOTE = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_SMOTE.fit(X_train_smote, y_train_smote)

prediction_test_smote = model_SMOTE.predict(X_test_smote)
print ("Accuracy of Random Forest after SMOTEENN = ", metrics.accuracy_score(y_test_smote, prediction_test_smote))
print("ROC AUC score for SVM model after SMOTEENN: ", roc_auc_score(y_test_smote, prediction_test_smote))
# Out:
# Accuracy of Random Forest after SMOTEENN =  0.95
# ROC AUC score for SVM model after SMOTEENN:  0.9384719405003381

# %%
(unique, counts) = np.unique(prediction_test_smote, return_counts=True)
print("Unique count: ",unique, counts)

cm = confusion_matrix(y_test_smote, prediction_test_smote)
print("Confusion Metrics After SMOTEENN: \n", cm)
# Out:
# Unique count:  [0 1] [53 27]
# Confusion Metrics After SMOTEENN:
#  [[50  1]
#  [ 3 26]]

# %%
print("Precision Values for: ")
P0 = cm[0,0] / (cm[0,0]+cm[1,0])
P1 = cm[1,1] / (cm[0,1]+cm[1,1])

print("  With NO Lung disease = ", P0)
print("  With Lung disease = ",   P1)
# Out:
# Precision Values for:
#   With NO Lung disease =  0.9433962264150944
#   With Lung disease =  0.9629629629629629

# %%
print("Recall Values for: ")
R0 = cm[0,0] / (cm[0,0]+cm[0,1])
R1 = cm[1,1] / (cm[1,1]+cm[1,0])
print("  With NO Lung disease = ", R0)
print("  With Lung disease = ", R1)
# Out:
# Recall Values for:
#   With NO Lung disease =  0.9803921568627451
#   With Lung disease =  0.896551724137931

# %%
print("F-Measure Values for: ")
print("  With NO Lung disease = ", (2 * P0 * R0)/ (P0 + R0))
print("  With Lung disease = ", (2 * P1 * R1)/ (P1 + R1))
# Out:
# F-Measure Values for:
#   With NO Lung disease =  0.9615384615384616
#   With Lung disease =  0.9285714285714286

# %%
from yellowbrick.classifier import ROCAUC
roc_auc=ROCAUC(model_SMOTE)
roc_auc.fit(X_train_smote, y_train_smote)
roc_auc.score(X_test_smote, y_test_smote)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# #ADASYN

# %%
from imblearn.over_sampling import ADASYN

X_adasyn, Y_adasyn = ADASYN().fit_resample(X, Y)
X_train_adasyn, X_test_adasyn, y_train_adasyn, y_test_adasyn = train_test_split(X_adasyn, Y_adasyn, test_size=0.2, random_state=42)

(unique, counts) = np.unique(Y, return_counts=True)
print("Original data: ", unique, counts)

(unique3, counts3) = np.unique(Y_adasyn, return_counts=True)
print("After ADASYN: ", unique3, counts3)
# Out:
# Original data:  [0 1] [167 416]
# After ADASYN:  [0 1] [388 416]

# %% [markdown]
# Logistic Regression

# %%
model_LR = LogisticRegression(max_iter=900)
model_LR.fit(X_train_adasyn, y_train_adasyn)
LR_prediction_adasyn = model_LR.predict(X_test_adasyn)

accuracy = metrics.accuracy_score(y_test_adasyn, LR_prediction_adasyn)
print("Accuracy:", accuracy)
print("ROC AUC score for Logestic Regression model after ADASYN: ",roc_auc_score(y_test_adasyn, LR_prediction_adasyn))
# Out:
# Accuracy: 0.6149068322981367
# ROC AUC score for Logestic Regression model after ADASYN:  0.6156992899042915

# %% [markdown]
# SVM

# %%
model_SVM = SVC(kernel='linear')
model_SVM.fit(X_train_adasyn, y_train_adasyn)
SVM_prediction_adasyn = model_SVM.predict(X_test_adasyn)

accuracy = metrics.accuracy_score(y_test_adasyn, SVM_prediction_adasyn)
print("Accuracy:", accuracy)
print("ROC AUC score for SVM model after ADASYN: ",roc_auc_score(y_test_adasyn, SVM_prediction_adasyn))
# Out:
# Accuracy: 0.5962732919254659
# ROC AUC score for SVM model after ADASYN:  0.6006483482556344

# %% [markdown]
# Random Forest

# %%
model_adasyn = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_adasyn.fit(X_train_adasyn, y_train_adasyn)

prediction_test_adasyn = model_adasyn.predict(X_test_adasyn)
print ("Accuracy = ", metrics.accuracy_score(y_test_adasyn, prediction_test_adasyn))
print("ROC AUC score for Random Forest model after ADASYN: ",roc_auc_score(y_test_adasyn, prediction_test_adasyn))
# Out:
# Accuracy =  0.782608695652174
# ROC AUC score for Random Forest model after ADASYN:  0.7831120716270454

# %%
#Confusion Matrix
(unique, counts) = np.unique(prediction_test_adasyn, return_counts=True)
print(unique, counts)

cm = confusion_matrix(y_test_adasyn, prediction_test_adasyn)
print("Confusion Metrics: \n",cm)
# Out:
# [0 1] [84 77]
# Confusion Metrics:
#  [[64 15]
#  [20 62]]

# %%
print("Precision Values for: ")
P0 = cm[0,0] / (cm[0,0]+cm[1,0])
P1 = cm[1,1] / (cm[0,1]+cm[1,1])

print("  With NO Lung disease = ", P0)
print("  With Lung disease = ",   P1)
# Out:
# Precision Values for:
#   With NO Lung disease =  0.7619047619047619
#   With Lung disease =  0.8051948051948052

# %%
#Print individual recall values for each class, based on the confusion matrix
print("Recall Values for: ")
R0 = cm[0,0] / (cm[0,0]+cm[0,1])
R1 = cm[1,1] / (cm[1,1]+cm[1,0])
print("  With NO Lung disease = ", R0)
print("  With Lung disease = ", R1)
# Out:
# Recall Values for:
#   With NO Lung disease =  0.810126582278481
#   With Lung disease =  0.7560975609756098

# %%
print("F-Measure Values for: ")
print("  With NO Lung disease = ", (2 * P0 * R0)/ (P0 + R0))
print("  With Lung disease = ", (2 * P1 * R1)/ (P1 + R1))
# Out:
# F-Measure Values for:
#   With NO Lung disease =  0.7852760736196319
#   With Lung disease =  0.7798742138364779

# %%
from yellowbrick.classifier import ROCAUC
roc_auc=ROCAUC(model_adasyn)
roc_auc.fit(X_train_adasyn, y_train_adasyn)
roc_auc.score(X_test_adasyn, y_test_adasyn)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
#  Technique 2: Up-sample minority class

# %%
from sklearn.utils import resample
print(df['Label'].value_counts())
# Out:
# 1    416
# 0    167
# Name: Label, dtype: int64

# %%
df_majority = df[df['Label'] == 1]  #Separate majority and minority classes
df_minority = df[df['Label'] == 0]

# Upsample minority class and other classes separately If not, random samples from combined classes
# will be duplicated and we run into same issue as before, undersampled remians undersampled.
df_minority_upsampled = resample(df_minority,
                                 replace=True,     # sample with replacement
                                 n_samples=416,    # to match average class
                                 random_state=42) # reproducible results

df_upsampled = pd.concat([df_majority, df_minority_upsampled]) # Combine majority class with upsampled minority class
print(df_upsampled['Label'].value_counts())
# Out:
# 1    416
# 0    416
# Name: Label, dtype: int64

# %%
Y_upsampled = df_upsampled["Label"].values

X_upsampled = df_upsampled.drop(labels = ["Label", "Gender"], axis=1)
X_upsampled = normalize(X_upsampled, axis=1)

X_train_upsampled, X_test_upsampled, y_train_upsampled, y_test_upsampled = train_test_split(X_upsampled, Y_upsampled, test_size=0.2, random_state=20)

# %% [markdown]
# #Train again with new upsamples data

# %% [markdown]
# Logistic Regression

# %%
model_LR = LogisticRegression(max_iter=900)
model_LR.fit(X_train_upsampled, y_train_upsampled)
LR_prediction_upsampling = model_LR.predict(X_test_upsampled)

accuracy = metrics.accuracy_score(y_test_upsampled, LR_prediction_upsampling)
print("Accuracy:", accuracy)
print("ROC AUC score for Logistic Regression model after ADASYN: ",roc_auc_score(y_test_upsampled, LR_prediction_upsampling))
# Out:
# Accuracy: 0.6287425149700598
# ROC AUC score for Logistic Regression model after ADASYN:  0.6443001443001443

# %% [markdown]
# SVM

# %%
model_SVM = SVC(kernel='linear')
model_SVM.fit(X_train_upsampled, y_train_upsampled)
SVM_prediction_upsampling = model_SVM.predict(X_test_upsampled)

accuracy = metrics.accuracy_score(y_test_upsampled, SVM_prediction_upsampling) # Calculate the accuracy of the SVM model after SMOTE
print("Accuracy:", accuracy)
print("ROC AUC score for SVM model after ADASYN: ",roc_auc_score(y_test_upsampled, SVM_prediction_upsampling))
# Out:
# Accuracy: 0.5808383233532934
# ROC AUC score for SVM model after ADASYN:  0.6092352092352092

# %% [markdown]
# RANDOM FOREST

# %%
model_RF_upsampled = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_RF_upsampled.fit(X_train_upsampled, y_train_upsampled)
prediction_test_RF_upsampled = model_RF_upsampled.predict(X_test_upsampled)

print("METRICS FOR BALANCED DATA USING UPSAMPLING : ")
print ("Accuracy = ", metrics.accuracy_score(y_test_upsampled, prediction_test_RF_upsampled))
print("ROC AUC score for Random Forest model after ADASYN: ",roc_auc_score(y_test_upsampled, prediction_test_RF_upsampled))
# Out:
# METRICS FOR BALANCED DATA USING UPSAMPLING :
# Accuracy =  0.8622754491017964
# ROC AUC score for Random Forest model after ADASYN:  0.8665945165945166

# %%
(unique, counts) = np.unique(prediction_test_RF_upsampled, return_counts=True)
print(unique, counts)
# Out:
# [0 1] [88 79]

# %%
cm_upsampled = confusion_matrix(y_test_upsampled, prediction_test_RF_upsampled)
print("Confusion Metrics after Upsampling: \n",cm_upsampled)
# Out:
# Confusion Metrics after Upsampling:
#  [[71  6]
#  [17 73]]

# %%
print("Precision Values for: ")
P0 = cm[0,0] / (cm[0,0]+cm[1,0])
P1 = cm[1,1] / (cm[0,1]+cm[1,1])

print("  With NO Lung disease = ", P0)
print("  With Lung disease = ",   P1)
# Out:
# Precision Values for:
#   With NO Lung disease =  0.7619047619047619
#   With Lung disease =  0.8051948051948052

# %%
print("Recall Values for: ")
R0 = cm[0,0] / (cm[0,0]+cm[0,1])
R1 = cm[1,1] / (cm[1,1]+cm[1,0])
print("  With NO Lung disease = ", R0)
print("  With Lung disease = ", R1)
# Out:
# Recall Values for:
#   With NO Lung disease =  0.810126582278481
#   With Lung disease =  0.7560975609756098

# %%
print("F-Measure Values for: ")
print("  With NO Lung disease = ", (2 * P0 * R0)/ (P0 + R0))
print("  With Lung disease = ", (2 * P1 * R1)/ (P1 + R1))
# Out:
# F-Measure Values for:
#   With NO Lung disease =  0.7852760736196319
#   With Lung disease =  0.7798742138364779

# %%
roc_auc=ROCAUC(model_RF_upsampled)
roc_auc.fit(X_train_upsampled, y_train_upsampled)
roc_auc.score(X_test_upsampled, y_test_upsampled)
roc_auc.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
'''
#SMOTE
X_smote, Y_smote = SMOTE().fit_resample(X_upsampled, Y_upsampled)

X_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, Y_smote, test_size=0.2, random_state=42)
(unique, counts) = np.unique(Y, return_counts=True)
print("Original data: ", unique, counts)
(unique2, counts2) = np.unique(Y_smote, return_counts=True)
print("After SMOTE: ", unique2, counts2)
model_upsampled_SMOTE = RandomForestClassifier(n_estimators = 25, random_state = 42)
model_upsampled_SMOTE.fit(X_train_smote, y_train_smote)
prediction_test_smote = model_SMOTE.predict(X_test_smote)
print ("Accuracy = ", metrics.accuracy_score(y_test_smote, prediction_test_smote))
print(roc_auc_score(y_test_smote, prediction_test_smote))
from yellowbrick.classifier import ROCAUC
roc_auc=ROCAUC(model_SMOTE)
roc_auc.fit(X_train_smote, y_train_smote)
roc_auc.score(X_test_smote, y_test_smote)
roc_auc.show()
'''
# Out:
# '\n#SMOTE\nX_smote, Y_smote = SMOTE().fit_resample(X_upsampled, Y_upsampled)\n\nX_train_smote, X_test_smote, y_train_smote, y_test_smote = train_test_split(X_smote, Y_smote, test_size=0.2, random_state=42)\n(unique, counts) = np.unique(Y, return_counts=True)\nprint("Original data: ", unique, counts)\n(unique2, counts2) = np.unique(Y_smote, return_counts=True)\nprint("After SMOTE: ", unique2, counts2)\nmodel_upsampled_SMOTE = RandomForestClassifier(n_estimators = 25, random_state = 42)\nmodel_upsampled_SMOTE.fit(X_train_smote, y_train_smote)\nprediction_test_smote = model_SMOTE.predict(X_test_smote)\nprint ("Accuracy = ", metrics.accuracy_score(y_test_smote, prediction_test_smote))\nprint(roc_auc_score(y_test_smote, prediction_test_smote))\nfrom yellowbrick.classifier import ROCAUC\nroc_auc=ROCAUC(model_SMOTE)\nroc_auc.fit(X_train_smote, y_train_smote)\nroc_auc.score(X_test_smote, y_test_smote)\nroc_auc.show()\n'

# %% [markdown]
# #ENSEMBLE METHODS

# %%
# AVERAGING METHOD
from sklearn.metrics import mean_squared_error

pred1 = LR_prediction_upsampling
pred2 = SVM_prediction_upsampling
pred3 = prediction_test_RF_upsampled

pred_final = (pred1+pred2+pred3)/3.0

# printing the mean squared error between real value and predicted value
print(mean_squared_error(y_test_upsampled, pred_final))
# Out:
# 0.21623419827012644

# %%
# MAX VOTING
from sklearn.metrics import log_loss
from sklearn.ensemble import VotingClassifier

model_1 = model_LR
model_2 = model_SVM
model_3 = model_RF

# Making the final model using voting classifier
final_model = VotingClassifier(estimators=[('logr', model_1), ('svm', model_2), ('rf', model_3)], voting='hard')

# training all the model on the train dataset
final_model.fit(X_train_upsampled, y_train_upsampled)

# predicting the output on the test dataset
pred_final = final_model.predict(X_test_upsampled)

# printing log loss between actual and predicted value
print(log_loss(y_test_upsampled, pred_final))
# Out:
# 11.870664289829003

# %%
pip install vecstack
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: vecstack in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vecstack) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vecstack) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from vecstack) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->vecstack) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->vecstack) (3.1.0)

# %%
# VOTING ENSEMBLE
from sklearn import model_selection
seed = 42
kfold = model_selection.KFold(n_splits=20)

estimators = [] # create different models

model_1 = LogisticRegression(); estimators.append(('logistic',model_1))
model_2 = SVC(); estimators.append(('svm',model_2))
model_3 = RandomForestClassifier(); estimators.append(('rf',model_3))

from sklearn.ensemble import VotingClassifier # create the ensemble model
ensemble = VotingClassifier(estimators)
results = model_selection.cross_val_score(ensemble, X_train_upsampled, y_train_upsampled, cv=kfold)
print(results.mean())
# Out:
# 0.620632798573975

# %%
'''
# TUNE ENSEMBLE
from sklearn.model_selection import cross_val_score, GridSearchCV

lr = LogisticRegression(solver='liblinear', random_state=1)
rf = RandomForestClassifier(max_features=9, n_jobs=4, random_state=1)
sv = SVC()

vc = VotingClassifier([('clf1',lr), ('clf2',rf), ('clf3',sv)]) # create an ensemble of 3 classifiers
cross_val_score(vc,X_train_smote, y_train_smote).mean()
param = {'voting':['hard', 'soft'], 'weights': [(1,1,1),(2,1,1),(1,2,1),(1,1,2)]} # define VotingClassifier parameters to search

grid = GridSearchCV(vc, param) #find the best set of parameters
grid.fit(X_train_smote, y_train_smote)
grid.best_score_
'''
# Out:
# "\n# TUNE ENSEMBLE\nfrom sklearn.model_selection import cross_val_score, GridSearchCV\n\nlr = LogisticRegression(solver='liblinear', random_state=1)\nrf = RandomForestClassifier(max_features=9, n_jobs=4, random_state=1)\nsv = SVC()\n\nvc = VotingClassifier([('clf1',lr), ('clf2',rf), ('clf3',sv)]) # create an ensemble of 3 classifiers\ncross_val_score(vc,X_train_smote, y_train_smote).mean()\nparam = {'voting':['hard', 'soft'], 'weights': [(1,1,1),(2,1,1),(1,2,1),(1,1,2)]} # define VotingClassifier parameters to search\n\ngrid = GridSearchCV(vc, param) #find the best set of parameters\ngrid.fit(X_train_smote, y_train_smote)\ngrid.best_score_\n"

# %% [markdown]
#  # k-folds validation

# %%
from sklearn.model_selection import cross_val_score
#In general, the more folds we use in k-fold cross-validation the lower the bias of the test MSE
#but the higher the variance. Conversely, the fewer folds we use the higher the bias but the lower the variance

scores = cross_val_score(model_RF, X_resampled, y_resampled, scoring='r2', cv=10) # 10 folds
print(scores)
# Out:
# [0.58333333 0.6875     0.89583333 0.89583333 0.47916667 0.27083333
#  0.38618926 0.48849105 0.4701087  0.78804348]

# %%
print(np.mean(scores))
# Out:
# 0.5945332480818415

# %%
from sklearn.model_selection import cross_val_predict
pred = cross_val_predict(model_RF, X_resampled, y_resampled)
#print(pred)

# %%
scores_test = cross_val_score(model_RF, X_resampled, y_resampled, cv=10)
print(scores_test)
# Out:
# [0.9        0.925      0.975      0.975      0.875      0.825
#  0.85       0.875      0.87179487 0.94871795]

# %%
print(np.mean(scores_test))
# Out:
# 0.902051282051282

# %% [markdown]
# KFold on Logestic Regression model

# %%
scores = cross_val_score(model_LR, X_resampled, y_resampled, scoring='r2', cv=10)
#print(scores)

print(np.mean(scores))

pred = cross_val_predict(model_LR, X_resampled, y_resampled)
#print(pred)

scores_test = cross_val_score(model_LR, X_resampled, y_resampled, cv=10)
#print(scores_test)

print(np.mean(scores_test))
# Out:
# -0.07041773231031535
# 0.7416025641025641

# %% [markdown]
# KFold on SVM model

# %%
scores = cross_val_score(model_SVM, X_resampled, y_resampled, scoring='r2', cv=10)
#print(scores)

print(np.mean(scores))

pred = cross_val_predict(model_SVM, X_resampled, y_resampled)
#print(pred)

scores_test = cross_val_score(model_SVM, X_resampled, y_resampled, cv=10)
#print(scores_test)

print(np.mean(scores_test))
# Out:
# -0.091624040920716
# 0.7366025641025642
